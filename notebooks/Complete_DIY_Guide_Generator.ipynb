# %% [markdown]
# # Complete DIY Home Improvement Guide Generator
#
# Generate comprehensive DIY guides with:
# - **Step-by-step instructions** with detailed explanations
# - **Visual guidance** with AI-generated images for each step
# - **Safety protocols** and precautions
# - **Tools & materials** with specifications
# - **Product recommendations** with pricing and comparison
# - **Purchase links** from major retailers (Home Depot, Lowe's, Amazon)
# - **Cost breakdown** and budget planning
#
# **Powered by:** Google Gemini 2.5 Flash & Imagen 4.0

# %% [markdown]
# ## 📋 Prerequisites & Setup
#
# **Required:**
# 1. Google AI Studio API key ([Get one here](https://aistudio.google.com/app/apikey))
# 2. Python packages: `google-genai`, `pillow`, `requests`
#
# **Set your API key:**
# ```powershell
# $env:GOOGLE_API_KEY = "your-api-key-here"
# ```

# %%
# Uncomment to install required packages
# %pip install --quiet google-genai pillow requests

# %% [markdown]
# ## 🔧 Import Libraries & Configure

# %%
import os
import json
import re
import textwrap
import pathlib
import base64
import io
from dataclasses import dataclass, field
from typing import List, Optional, Dict, Any
from datetime import datetime

import google.generativeai as genai
from google import genai as genai_client
from google.genai import types
from PIL import Image
from IPython.display import display, Markdown, HTML

# Verify API key
API_KEY = os.getenv('GOOGLE_API_KEY')
if not API_KEY:
    raise RuntimeError(
        '❌ Missing GOOGLE_API_KEY environment variable.\n'
        'Set it in PowerShell: $env:GOOGLE_API_KEY = "your-key"'
    )

# Configure Gemini
genai.configure(api_key=API_KEY)
imagen_client = genai_client.Client(api_key=API_KEY)

# Model configuration
TEXT_MODEL_NAME = 'gemini-2.5-flash'
IMAGE_MODEL_NAME = 'imagen-4.0-generate-001'

# Create exports directory
EXPORTS_DIR = pathlib.Path('../exports/diy_guides')
EXPORTS_DIR.mkdir(parents=True, exist_ok=True)

print('✅ Configuration loaded successfully!')
print(f'📝 Text Model: {TEXT_MODEL_NAME}')
print(f'🎨 Image Model: {IMAGE_MODEL_NAME}')
print(f'📁 Export Directory: {EXPORTS_DIR.absolute()}')
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ✅ Configuration loaded successfully!
# 📝 Text Model: gemini-2.5-flash
# 🎨 Image Model: imagen-4.0-generate-001
# 📁 Export Directory: c:\Users\ramma\Documents\augment-projects\augment\notebooks\..\exports\diy_guides

# %% [markdown]
# ## 📚 Data Structures

# %%
@dataclass
class Product:
    """Product information with pricing and purchase options."""
    name: str
    category: str  # 'material' or 'tool'
    description: str
    specifications: Optional[str] = None
    estimated_price: Optional[str] = None
    retailers: List[Dict[str, str]] = field(default_factory=list)  # [{'name': 'Home Depot', 'price': '$XX.XX', 'url': '...'}]
    alternatives: Optional[List[str]] = None
    rental_option: Optional[str] = None  # For tools that can be rented

@dataclass
class SafetyGuideline:
    """Safety information with warnings and requirements."""
    category: str  # 'warning', 'protective_equipment', 'precaution'
    description: str
    importance: str  # 'critical', 'high', 'medium'

@dataclass
class GuideStep:
    """Single step in the DIY guide."""
    step_number: int
    title: str
    description: str
    detailed_instructions: List[str]
    tips: Optional[List[str]] = None
    warnings: Optional[List[str]] = None
    common_mistakes: Optional[List[str]] = None  # Common mistakes to avoid
    quality_checkpoints: Optional[List[str]] = None  # Quality checks for this step
    image_prompt: Optional[str] = None
    image_path: Optional[str] = None
    required_products: Optional[List[str]] = None  # Product names referenced

@dataclass
class CostBreakdown:
    """Project cost analysis."""
    materials_cost: Dict[str, float]  # {product_name: price}
    tools_cost: Dict[str, float]
    total_materials: float
    total_tools: float
    total_project: float
    cost_notes: Optional[List[str]] = None

@dataclass
class CompleteDIYGuide:
    """Complete DIY guide with all information."""
    # Basic Info
    topic: str
    difficulty: str
    duration_estimate: str
    overview: str
    
    # Safety
    safety_guidelines: List[SafetyGuideline]
    
    # Products
    materials: List[Product]
    tools: List[Product]
    
    # Instructions
    preparation_steps: List[str]
    steps: List[GuideStep]
    
    # Cost
    cost_breakdown: CostBreakdown
    
    # Additional Info
    cleanup_instructions: Optional[str] = None
    maintenance_tips: Optional[List[str]] = None
    troubleshooting: Optional[Dict[str, str]] = None
    permits_required: Optional[str] = None
    
    # Metadata
    generated_date: str = field(default_factory=lambda: datetime.now().strftime('%Y-%m-%d'))

print('✅ Data structures defined')
# Out:
# ✅ Data structures defined

# %% [markdown]
# ## 🤖 Initialize AI Models

# %%
# Initialize text generation model
text_model = genai.GenerativeModel(TEXT_MODEL_NAME)
print(f'✅ Text model initialized: {TEXT_MODEL_NAME}')
print(f'✅ Image generation client ready: {IMAGE_MODEL_NAME}')
# Out:
# ✅ Text model initialized: gemini-2.5-flash
# ✅ Image generation client ready: imagen-4.0-generate-001

# %% [markdown]
# ## 🎯 Guide Generation Functions

# %%
def build_comprehensive_guide_prompt(topic: str, budget_range: str = 'moderate') -> str:
    """Build a comprehensive prompt for complete DIY guide generation."""
    
    system_instructions = textwrap.dedent(f'''
    You are an expert DIY home improvement consultant with 20+ years of experience in
    construction, remodeling, and teaching homeowners. Create a COMPLETE, professional
    DIY guide that covers every aspect of the project.
    
    Project Budget Range: {budget_range}
    
    REQUIREMENTS:
    
    1. OVERVIEW & PLANNING:
       - Clear project description with benefits
       - Realistic difficulty assessment
       - Accurate time estimate (prep + work + cleanup)
       - Required skill level
    
    2. SAFETY GUIDELINES:
       - Critical warnings (electrical, structural, chemical hazards)
       - Required protective equipment (specific items)
       - Important precautions
       - When to call a professional
    
    3. MATERIALS LIST:
       - Specific products with brand recommendations
       - Exact quantities needed
       - Specifications (sizes, ratings, grades)
       - Estimated prices (realistic US prices)
       - Alternative options (budget/premium)
       - Where to buy (Home Depot, Lowe\'s, Amazon product names)
    
    4. TOOLS LIST:
       - All required tools (basic and specialized)
       - Tool specifications
       - Purchase vs rental recommendations
       - Estimated costs
       - Alternative tools
    
    5. STEP-BY-STEP INSTRUCTIONS:
       - Detailed preparation steps
       - Numbered main steps with clear titles
       - Multiple sub-instructions per step
       - Pro tips and tricks
       - Common mistakes to avoid
       - Quality checkpoints
    
    6. COST BREAKDOWN:
       - Individual material costs
       - Individual tool costs
       - Total materials cost
       - Total tools cost (one-time)
       - Overall project total
       - Cost-saving tips
    
    7. FINISHING TOUCHES:
       - Cleanup and disposal instructions
       - Maintenance recommendations
       - Troubleshooting common issues
       - Permit/inspection requirements if any
    
    FORMAT REQUIREMENTS:
    - Use US measurements only
    - Include real product names from major US retailers
    - Provide realistic price ranges
    - Be specific with quantities (e.g., "2 boxes of 1-1/4 inch screws (100ct)")
    - Include model numbers or specific product lines when relevant
    - Suggest both in-store and online purchase options
    ''')
    
    json_schema = textwrap.dedent('''
    Return ONLY valid JSON with this structure:
    {
      "topic": "string",
      "difficulty": "Beginner|Intermediate|Advanced",
      "duration_estimate": "string",
      "overview": "string (2-3 paragraphs)",
      "permits_required": "string or null",
      
      "safety_guidelines": [
        {
          "category": "warning|protective_equipment|precaution",
          "description": "string",
          "importance": "critical|high|medium"
        }
      ],
      
      "materials": [
        {
          "name": "string",
          "category": "material",
          "description": "string (what it\'s for)",
          "specifications": "string (size, quantity, grade)",
          "estimated_price": "string ($X.XX - $Y.YY)",
          "retailers": [
            {
              "name": "Home Depot|Lowe\'s|Amazon|etc",
              "price": "$XX.XX",
              "product_name": "specific product name or brand",
              "notes": "optional availability notes"
            }
          ],
          "alternatives": ["string"] (optional)
        }
      ],
      
      "tools": [
        {
          "name": "string",
          "category": "tool",
          "description": "string",
          "specifications": "string",
          "estimated_price": "string",
          "retailers": [...],
          "alternatives": ["string"] (optional),
          "rental_option": "string (if applicable)"
        }
      ],
      
      "preparation_steps": ["string"],
      
      "steps": [
        {
          "step_number": 1,
          "title": "string",
          "description": "string (brief overview)",
          "detailed_instructions": ["string"],
          "tips": ["string"] (optional),
          "warnings": ["string"] (optional),
          "image_prompt": "string (detailed description for AI image generation)",
          "required_products": ["string"] (product names from materials/tools)
        }
      ],
      
      "cost_breakdown": {
        "materials_cost": {"product_name": 25.99},
        "tools_cost": {"tool_name": 49.99},
        "total_materials": 150.00,
        "total_tools": 200.00,
        "total_project": 350.00,
        "cost_notes": ["string"] (optional)
      },
      
      "cleanup_instructions": "string",
      "maintenance_tips": ["string"],
      "troubleshooting": {"problem": "solution"}
    }
    ''')
    
    return f"{system_instructions}\n\nTopic: {topic}\n\n{json_schema}"

print('✅ Prompt builder defined')
# Out:
# ✅ Prompt builder defined

# %%
def parse_guide_response(response_text: str, topic: str) -> CompleteDIYGuide:
    """Parse the JSON response and create a CompleteDIYGuide object."""
    
    # Clean response text - handle markdown code blocks
    response_text = response_text.strip()
    
    # Remove markdown code blocks if present
    if response_text.startswith('```'):
        # Find the first opening ``` and remove it with any language identifier
        response_text = re.sub(r'^```[a-z]*\s*\n', '', response_text)
        # Remove the closing ```
        response_text = re.sub(r'\n```\s*$', '', response_text)
        response_text = response_text.strip()
    
    # Try to parse JSON
    data = None
    try:
        data = json.loads(response_text)
        print(f"✅ Successfully parsed JSON response")
    except json.JSONDecodeError as e:
        print(f"⚠️ Initial JSON parsing failed: {str(e)}")
        print(f"Error at line {e.lineno}, column {e.colno}, char {e.pos}")
        
        # Check if JSON is truncated
        if not response_text.rstrip().endswith('}'):
            print(f"⚠️ JSON appears to be truncated - attempting to fix...")
            
            # Try to close truncated strings and objects
            response_text = response_text.rstrip()
            
            # If we're in the middle of a string, close it
            # Count quotes to see if we're in a string
            quote_count = response_text.count('"') - response_text.count('\\"')
            if quote_count % 2 == 1:  # Odd number means unclosed string
                print("   Closing unclosed string...")
                response_text += '"'
            
            # Count open braces and brackets
            open_braces = response_text.count('{') - response_text.count('}')
            open_brackets = response_text.count('[') - response_text.count(']')
            
            # Close any open arrays
            if open_brackets > 0:
                print(f"   Closing {open_brackets} open array(s)...")
                response_text += ']' * open_brackets
            
            # Close any open objects
            if open_braces > 0:
                print(f"   Closing {open_braces} open object(s)...")
                response_text += '}' * open_braces
            
            # Try parsing again
            try:
                data = json.loads(response_text)
                print(f"✅ Successfully parsed fixed JSON")
            except json.JSONDecodeError as e2:
                print(f"⚠️ Still failed after attempting to fix: {str(e2)}")
        
        # If still no data, try extracting from start
        if data is None:
            print(f"Attempting to extract valid JSON from response...")
            
            # Find the first { and try to parse from there
            start_idx = response_text.find('{')
            if start_idx == -1:
                raise ValueError(f'No JSON object found in response.\n\nFirst 500 chars:\n{response_text[:500]}')
            
            # Try to extract complete JSON by finding matching braces
            depth = 0
            in_string = False
            escape_next = False
            end_idx = -1
            
            for i in range(start_idx, len(response_text)):
                char = response_text[i]
                
                # Handle string escape sequences
                if escape_next:
                    escape_next = False
                    continue
                    
                if char == '\\' and in_string:
                    escape_next = True
                    continue
                
                # Handle strings (don't count braces inside strings)
                if char == '"':
                    in_string = not in_string
                    continue
                
                # Only count braces outside of strings
                if not in_string:
                    if char == '{':
                        depth += 1
                    elif char == '}':
                        depth -= 1
                        if depth == 0:
                            end_idx = i + 1
                            break
            
            if end_idx == -1:
                print(f"⚠️ Could not find matching braces")
                raise ValueError(f'Could not find complete JSON object in response.')
            else:
                json_str = response_text[start_idx:end_idx]
                try:
                    data = json.loads(json_str)
                    print(f"✅ Successfully parsed extracted JSON")
                except json.JSONDecodeError as e3:
                    print(f"⚠️ Extracted JSON parsing failed: {str(e3)}")
                    raise ValueError(f'Could not parse extracted JSON.\n\nError: {str(e3)}')
    
    if data is None:
        raise ValueError("Failed to parse JSON from response")
    
    # Parse safety guidelines
    safety_guidelines = [
        SafetyGuideline(**sg) for sg in data.get('safety_guidelines', [])
    ]
    
    # Parse materials
    materials = [
        Product(**{**m, 'category': 'material'}) for m in data.get('materials', [])
    ]
    
    # Parse tools
    tools = [
        Product(**{**t, 'category': 'tool'}) for t in data.get('tools', [])
    ]
    
    # Parse steps
    steps = [
        GuideStep(**step) for step in data.get('steps', [])
    ]
    
    # Parse cost breakdown
    cost_data = data.get('cost_breakdown', {})
    cost_breakdown = CostBreakdown(
        materials_cost=cost_data.get('materials_cost', {}),
        tools_cost=cost_data.get('tools_cost', {}),
        total_materials=cost_data.get('total_materials', 0.0),
        total_tools=cost_data.get('total_tools', 0.0),
        total_project=cost_data.get('total_project', 0.0),
        cost_notes=cost_data.get('cost_notes')
    )
    
    # Create guide object
    guide = CompleteDIYGuide(
        topic=data.get('topic', topic),
        difficulty=data.get('difficulty', 'Intermediate'),
        duration_estimate=data.get('duration_estimate', 'Varies'),
        overview=data.get('overview', ''),
        safety_guidelines=safety_guidelines,
        materials=materials,
        tools=tools,
        preparation_steps=data.get('preparation_steps', []),
        steps=steps,
        cost_breakdown=cost_breakdown,
        cleanup_instructions=data.get('cleanup_instructions'),
        maintenance_tips=data.get('maintenance_tips'),
        troubleshooting=data.get('troubleshooting'),
        permits_required=data.get('permits_required')
    )
    
    return guide

print('✅ Response parser defined with robust JSON extraction and repair')
# Out:
# ✅ Response parser defined with robust JSON extraction and repair

# %%
# DEBUG: Test the raw API response
def test_raw_response(topic: str = "How to Install a Ceiling Fan"):
    """Test what we get from the API."""
    print(f'🔍 Testing API for: {topic}\n')
    
    prompt = build_comprehensive_guide_prompt(topic, 'moderate')
    
    response = text_model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            temperature=0.7,
            max_output_tokens=8000,
        )
    )
    
    response_text = response.text if hasattr(response, 'text') else str(response)
    
    print("="*80)
    print("RAW RESPONSE (first 2000 characters):")
    print("="*80)
    print(response_text[:2000])
    print("\n" + "="*80)
    print(f"Response type: {type(response_text)}")
    print(f"Response length: {len(response_text)}")
    print("="*80)
    
    # Try to find JSON
    if response_text.startswith('```'):
        print("\n⚠️ Response starts with markdown code block")
    if '{' in response_text:
        first_brace = response_text.find('{')
        print(f"\n✓ First '{{' found at position {first_brace}")
        print(f"Characters before first brace: {repr(response_text[:first_brace])}")
    else:
        print("\n❌ No '{' found in response!")
    
    return response_text

# Run the test
test_response = test_raw_response()
# Out:
# 🔍 Testing API for: How to Install a Ceiling Fan
#
# ================================================================================
# RAW RESPONSE (first 2000 characters):
# ================================================================================
# ```json
# {
#   "topic": "How to Install a Ceiling Fan",
#   "difficulty": "Intermediate",
#   "duration_estimate": "3-6 hours (including prep, work, and cleanup)",
#   "overview": "Installing a ceiling fan is a fantastic DIY project that can significantly enhance the comfort and aesthetics of almost any room in your home. Not only does it provide a refreshing breeze during warmer months, but many models also include integrated lighting, offering both ambient and task illumination. This project is ideal for improving air circulation, reducing reliance on air conditioning, and adding a stylish focal point to your living space. While it involves basic electrical wiring and working overhead, it's a manageable task for homeowners comfortable with following detailed instructions and adhering to strict safety protocols.\n\nThis comprehensive guide will walk you through every step, from selecting the right fan and ensuring you have the proper electrical support, to making the connections and mounting the fixture securely. We'll cover essential safety measures, provide a detailed list of materials and tools, and offer expert tips to help you achieve a professional-looking and fully functional installation. By tackling this project yourself, you'll gain valuable home improvement skills and enjoy the satisfaction of a job well done, all while saving on professional installation costs.\n\nWhether you're replacing an old, outdated fixture or adding a fan to a room that currently only has a basic light, this guide is designed to empower you with the knowledge and confidence to complete the installation safely and efficiently. Remember, preparation and attention to detail are key to a successful outcome.",
#   "permits_required": "Generally, a permit is NOT required for replacing an existing ceiling fan or light fixture with a new ceiling fan, as long as you are using existing wiring and a fan-rated electrical box. However, if you are installing a NEW electrical circuit for the fan, making s
#
# ================================================================================
# Response type: <class 'str'>
# Response length: 22344
# ================================================================================
#
# ⚠️ Response starts with markdown code block
#
# ✓ First '{' found at position 8
# Characters before first brace: '```json\n'
# ================================================================================
# RAW RESPONSE (first 2000 characters):
# ================================================================================
# ```json
# {
#   "topic": "How to Install a Ceiling Fan",
#   "difficulty": "Intermediate",
#   "duration_estimate": "3-6 hours (including prep, work, and cleanup)",
#   "overview": "Installing a ceiling fan is a fantastic DIY project that can significantly enhance the comfort and aesthetics of almost any room in your home. Not only does it provide a refreshing breeze during warmer months, but many models also include integrated lighting, offering both ambient and task illumination. This project is ideal for improving air circulation, reducing reliance on air conditioning, and adding a stylish focal point to your living space. While it involves basic electrical wiring and working overhead, it's a manageable task for homeowners comfortable with following detailed instructions and adhering to strict safety protocols.\n\nThis comprehensive guide will walk you through every step, from selecting the right fan and ensuring you have the proper electrical support, to making the connections and mounting the fixture securely. We'll cover essential safety measures, provide a detailed list of materials and tools, and offer expert tips to help you achieve a professional-looking and fully functional installation. By tackling this project yourself, you'll gain valuable home improvement skills and enjoy the satisfaction of a job well done, all while saving on professional installation costs.\n\nWhether you're replacing an old, outdated fixture or adding a fan to a room that currently only has a basic light, this guide is designed to empower you with the knowledge and confidence to complete the installation safely and efficiently. Remember, preparation and attention to detail are key to a successful outcome.",
#   "permits_required": "Generally, a permit is NOT required for replacing an existing ceiling fan or light fixture with a new ceiling fan, as long as you are using existing wiring and a fan-rated electrical box. However, if you are installing a NEW electrical circuit for the fan, making s
#
# ================================================================================
# Response type: <class 'str'>
# Response length: 22344
# ================================================================================
#
# ⚠️ Response starts with markdown code block
#
# ✓ First '{' found at position 8
# Characters before first brace: '```json\n'

# %%
# DEBUG: Let's test the API response to see what we're getting
def debug_api_response(topic: str):
    """Debug function to see the raw API response."""
    print(f'🔍 Testing API response for: {topic}\n')
    
    prompt = build_comprehensive_guide_prompt(topic, 'moderate')
    
    response = text_model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            temperature=0.7,
            max_output_tokens=8000,
        )
    )
    
    response_text = response.text if hasattr(response, 'text') else str(response)
    
    print("="*80)
    print("RAW RESPONSE (first 2000 characters):")
    print("="*80)
    print(response_text[:2000])
    print("="*80)
    
    return response_text

# Test it now:
test_response = debug_api_response("How to Install a Ceiling Fan")
# Out:
# 🔍 Testing API response for: How to Install a Ceiling Fan
#
# ================================================================================
# RAW RESPONSE (first 2000 characters):
# ================================================================================
# ```json
# {
#   "topic": "How to Install a Ceiling Fan",
#   "difficulty": "Intermediate",
#   "duration_estimate": "4 to 8 hours (including prep, installation, and cleanup)",
#   "overview": "Upgrading your home with a new ceiling fan is a fantastic DIY project that significantly enhances comfort and aesthetic appeal. A ceiling fan provides a gentle breeze to cool down a room during warmer months, allowing you to potentially raise your thermostat settings and save on energy bills. In cooler months, many fans offer a reverse setting to circulate warm air trapped near the ceiling, improving heating efficiency.\n\nThis guide will walk you through the process of safely and correctly installing a ceiling fan, whether you're replacing an old fixture or adding a fan to a pre-wired location. We'll cover everything from ensuring proper electrical support and structural integrity to making secure wire connections and final assembly. With careful planning and adherence to safety protocols, you can successfully complete this project and enjoy the benefits of improved air circulation and integrated lighting.\n\nWhile this project involves working with electricity and at heights, it's well within the capabilities of an intermediate DIYer who is comfortable following detailed instructions and has a basic understanding of home electrical systems. Always prioritize safety, and don't hesitate to call a professional if you encounter unexpected challenges or feel unsure at any point.",
#   "permits_required": "Generally, a permit is not required for directly replacing an existing light fixture with a ceiling fan, or installing a fan in a location that already has a properly installed, fan-rated electrical box and wiring. However, if you are running new electrical circuits, making significant structural modifications to support the fan, or if your local municipality has specific requirements, a permit may be necessary. Always check with your local building department for specific regulations in yo
# ================================================================================
# ================================================================================
# RAW RESPONSE (first 2000 characters):
# ================================================================================
# ```json
# {
#   "topic": "How to Install a Ceiling Fan",
#   "difficulty": "Intermediate",
#   "duration_estimate": "4 to 8 hours (including prep, installation, and cleanup)",
#   "overview": "Upgrading your home with a new ceiling fan is a fantastic DIY project that significantly enhances comfort and aesthetic appeal. A ceiling fan provides a gentle breeze to cool down a room during warmer months, allowing you to potentially raise your thermostat settings and save on energy bills. In cooler months, many fans offer a reverse setting to circulate warm air trapped near the ceiling, improving heating efficiency.\n\nThis guide will walk you through the process of safely and correctly installing a ceiling fan, whether you're replacing an old fixture or adding a fan to a pre-wired location. We'll cover everything from ensuring proper electrical support and structural integrity to making secure wire connections and final assembly. With careful planning and adherence to safety protocols, you can successfully complete this project and enjoy the benefits of improved air circulation and integrated lighting.\n\nWhile this project involves working with electricity and at heights, it's well within the capabilities of an intermediate DIYer who is comfortable following detailed instructions and has a basic understanding of home electrical systems. Always prioritize safety, and don't hesitate to call a professional if you encounter unexpected challenges or feel unsure at any point.",
#   "permits_required": "Generally, a permit is not required for directly replacing an existing light fixture with a ceiling fan, or installing a fan in a location that already has a properly installed, fan-rated electrical box and wiring. However, if you are running new electrical circuits, making significant structural modifications to support the fan, or if your local municipality has specific requirements, a permit may be necessary. Always check with your local building department for specific regulations in yo
# ================================================================================

# %%
def generate_complete_guide(topic: str, budget_range: str = 'moderate', generate_images: bool = True) -> CompleteDIYGuide:
    """Generate a complete DIY guide with all information."""
    
    print(f'🔄 Generating complete DIY guide for: {topic}')
    print(f'💰 Budget range: {budget_range}')
    print(f'🎨 Generate images: {generate_images}')
    print()
    
    # Generate guide content
    print('📝 Step 1: Generating guide content...')
    prompt = build_comprehensive_guide_prompt(topic, budget_range)
    
    # Use higher max_output_tokens to avoid truncation
    response = text_model.generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(
            temperature=0.7,
            max_output_tokens=16000,  # Increased from 8000
            response_mime_type="application/json",  # Request JSON directly
        )
    )
    
    response_text = response.text if hasattr(response, 'text') else str(response)
    
    # Check if response looks truncated
    if not response_text.rstrip().endswith('}'):
        print(f"⚠️ Warning: Response may be truncated (doesn't end with '}}')")
        print(f"Response length: {len(response_text)} characters")
        print(f"Last 200 characters: ...{response_text[-200:]}")
    
    guide = parse_guide_response(response_text, topic)
    print(f'✅ Generated {len(guide.steps)} steps with {len(guide.materials)} materials and {len(guide.tools)} tools')
    
    # Generate images if requested
    if generate_images and len(guide.steps) > 0:
        print(f'\n🎨 Step 2: Generating images for {len(guide.steps)} steps...')
        
        # Create images directory
        images_dir = EXPORTS_DIR / 'images' / re.sub(r'[^a-z0-9]+', '_', topic.lower())
        images_dir.mkdir(parents=True, exist_ok=True)
        
        for i, step in enumerate(guide.steps, 1):
            if step.image_prompt:
                try:
                    print(f'  Generating image {i}/{len(guide.steps)}: {step.title[:50]}...')
                    
                    # Generate image
                    image_response = imagen_client.models.generate_images(
                        model=IMAGE_MODEL_NAME,
                        prompt=step.image_prompt,
                        config=types.GenerateImagesConfig(
                            number_of_images=1,
                            aspect_ratio='16:9',
                            safety_filter_level='block_some',
                            person_generation='allow_adult'
                        )
                    )
                    
                    if image_response.generated_images:
                        # Save image
                        img_data = image_response.generated_images[0].image.image_bytes
                        img = Image.open(io.BytesIO(img_data))
                        
                        img_filename = f'step_{i:02d}_{re.sub(r"[^a-z0-9]+", "_", step.title.lower())}.png'
                        img_path = images_dir / img_filename
                        img.save(img_path)
                        
                        step.image_path = str(img_path)
                        print(f'    ✅ Saved: {img_filename}')
                    
                except Exception as e:
                    print(f'    ⚠️ Failed to generate image: {str(e)[:100]}')
        
        print('✅ Image generation complete')
    
    print(f'\n✅ Complete guide generated successfully!')
    return guide

print('✅ Guide generator defined')
# Out:
# ✅ Guide generator defined

# %% [markdown]
# ## 📄 Export Functions

# %%
def format_currency(amount: float) -> str:
    """Format a number as US currency."""
    return f"${amount:,.2f}"

def export_guide_to_markdown(guide: CompleteDIYGuide, filename: Optional[str] = None) -> str:
    """Export guide to a beautiful markdown file."""
    
    if not filename:
        filename = f"{re.sub(r'[^a-z0-9]+', '_', guide.topic.lower())}.md"
    
    filepath = EXPORTS_DIR / filename
    
    # Build markdown content
    md_lines = []
    
    # Header
    md_lines.extend([
        f"# {guide.topic}",
        "",
        f"**Difficulty:** {guide.difficulty} | ",
        f"**Time Required:** {guide.duration_estimate} | ",
        f"**Estimated Cost:** {format_currency(guide.cost_breakdown.total_project)}",
        "",
        f"*Generated: {guide.generated_date}*",
        "",
        "---",
        ""
    ])
    
    # Overview
    md_lines.extend([
        "## 📋 Overview",
        "",
        guide.overview,
        ""
    ])
    
    # Permits
    if guide.permits_required:
        md_lines.extend([
            "### 📜 Permits & Inspections",
            "",
            guide.permits_required,
            ""
        ])
    
    # Safety Guidelines
    md_lines.extend([
        "## ⚠️ Safety Guidelines",
        ""
    ])
    
    # Group by importance
    critical = [sg for sg in guide.safety_guidelines if sg.importance == 'critical']
    high = [sg for sg in guide.safety_guidelines if sg.importance == 'high']
    medium = [sg for sg in guide.safety_guidelines if sg.importance == 'medium']
    
    if critical:
        md_lines.append("### 🚨 Critical Safety Warnings")
        md_lines.append("")
        for sg in critical:
            md_lines.append(f"- **{sg.category.replace('_', ' ').title()}:** {sg.description}")
        md_lines.append("")
    
    if high:
        md_lines.append("### ⚡ Important Precautions")
        md_lines.append("")
        for sg in high:
            md_lines.append(f"- **{sg.category.replace('_', ' ').title()}:** {sg.description}")
        md_lines.append("")
    
    if medium:
        md_lines.append("### ✓ Additional Safety Tips")
        md_lines.append("")
        for sg in medium:
            md_lines.append(f"- {sg.description}")
        md_lines.append("")
    
    # Materials
    md_lines.extend([
        "## 🛒 Materials List",
        "",
        f"**Total Materials Cost:** {format_currency(guide.cost_breakdown.total_materials)}",
        ""
    ])
    
    for i, material in enumerate(guide.materials, 1):
        md_lines.append(f"### {i}. {material.name}")
        md_lines.append("")
        md_lines.append(f"**Purpose:** {material.description}")
        if material.specifications:
            md_lines.append(f"**Specifications:** {material.specifications}")
        if material.estimated_price:
            md_lines.append(f"**Price Range:** {material.estimated_price}")
        md_lines.append("")
        
        if material.retailers:
            md_lines.append("**Where to Buy:**")
            md_lines.append("")
            for retailer in material.retailers:
                product_info = retailer.get('product_name', '')
                price = retailer.get('price', 'N/A')
                notes = retailer.get('notes', '')
                md_lines.append(f"- **{retailer['name']}:** {price}")
                if product_info:
                    md_lines.append(f"  - Product: {product_info}")
                if notes:
                    md_lines.append(f"  - Note: {notes}")
            md_lines.append("")
        
        if material.alternatives:
            md_lines.append("**Alternatives:**")
            for alt in material.alternatives:
                md_lines.append(f"- {alt}")
            md_lines.append("")
    
    # Tools
    md_lines.extend([
        "## 🔧 Tools Required",
        "",
        f"**Total Tools Cost:** {format_currency(guide.cost_breakdown.total_tools)} *(one-time investment)*",
        ""
    ])
    
    for i, tool in enumerate(guide.tools, 1):
        md_lines.append(f"### {i}. {tool.name}")
        md_lines.append("")
        md_lines.append(f"**Use:** {tool.description}")
        if tool.specifications:
            md_lines.append(f"**Specs:** {tool.specifications}")
        if tool.estimated_price:
            md_lines.append(f"**Price Range:** {tool.estimated_price}")
        md_lines.append("")
        
        if tool.retailers:
            md_lines.append("**Where to Buy:**")
            md_lines.append("")
            for retailer in tool.retailers:
                product_info = retailer.get('product_name', '')
                price = retailer.get('price', 'N/A')
                md_lines.append(f"- **{retailer['name']}:** {price}")
                if product_info:
                    md_lines.append(f"  - Product: {product_info}")
            md_lines.append("")
    
    # Cost Breakdown
    md_lines.extend([
        "## 💰 Cost Breakdown",
        "",
        "### Materials",
        ""
    ])
    
    for item, cost in guide.cost_breakdown.materials_cost.items():
        md_lines.append(f"- {item}: {format_currency(cost)}")
    
    md_lines.extend([
        "",
        f"**Subtotal Materials:** {format_currency(guide.cost_breakdown.total_materials)}",
        "",
        "### Tools",
        ""
    ])
    
    for item, cost in guide.cost_breakdown.tools_cost.items():
        md_lines.append(f"- {item}: {format_currency(cost)}")
    
    md_lines.extend([
        "",
        f"**Subtotal Tools:** {format_currency(guide.cost_breakdown.total_tools)}",
        "",
        f"### 🎯 Total Project Cost: {format_currency(guide.cost_breakdown.total_project)}",
        ""
    ])
    
    if guide.cost_breakdown.cost_notes:
        md_lines.append("**Cost Notes:**")
        for note in guide.cost_breakdown.cost_notes:
            md_lines.append(f"- {note}")
        md_lines.append("")
    
    # Preparation
    if guide.preparation_steps:
        md_lines.extend([
            "## 🎯 Preparation",
            ""
        ])
        for i, step in enumerate(guide.preparation_steps, 1):
            md_lines.append(f"{i}. {step}")
        md_lines.append("")
    
    # Step-by-step instructions
    md_lines.extend([
        "## 📖 Step-by-Step Instructions",
        ""
    ])
    
    for step in guide.steps:
        md_lines.append(f"### Step {step.step_number}: {step.title}")
        md_lines.append("")
        md_lines.append(step.description)
        md_lines.append("")
        
        # Image
        if step.image_path:
            md_lines.append(f"![Step {step.step_number}]({step.image_path})")
            md_lines.append("")
        
        # Detailed instructions
        md_lines.append("**Instructions:**")
        md_lines.append("")
        for i, instruction in enumerate(step.detailed_instructions, 1):
            md_lines.append(f"{i}. {instruction}")
        md_lines.append("")
        
        # Required products
        if step.required_products:
            md_lines.append("**Required Products:**")
            for product in step.required_products:
                md_lines.append(f"- {product}")
            md_lines.append("")
        
        # Tips
        if step.tips:
            md_lines.append("**💡 Pro Tips:**")
            for tip in step.tips:
                md_lines.append(f"- {tip}")
            md_lines.append("")
        
        # Warnings
        if step.warnings:
            md_lines.append("**⚠️ Warnings:**")
            for warning in step.warnings:
                md_lines.append(f"- {warning}")
            md_lines.append("")
        
        md_lines.append("---")
        md_lines.append("")
    
    # Cleanup
    if guide.cleanup_instructions:
        md_lines.extend([
            "## 🧹 Cleanup & Disposal",
            "",
            guide.cleanup_instructions,
            ""
        ])
    
    # Maintenance
    if guide.maintenance_tips:
        md_lines.extend([
            "## 🔧 Maintenance Tips",
            ""
        ])
        for tip in guide.maintenance_tips:
            md_lines.append(f"- {tip}")
        md_lines.append("")
    
    # Troubleshooting
    if guide.troubleshooting:
        md_lines.extend([
            "## 🔍 Troubleshooting",
            ""
        ])
        for problem, solution in guide.troubleshooting.items():
            md_lines.append(f"**Problem:** {problem}")
            md_lines.append(f"**Solution:** {solution}")
            md_lines.append("")
    
    # Footer
    md_lines.extend([
        "---",
        "",
        "*This guide was generated using AI and should be used as a reference. Always follow manufacturer instructions and local building codes. Consult professionals when needed.*",
        ""
    ])
    
    # Write to file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write('\n'.join(md_lines))
    
    print(f'✅ Exported to: {filepath}')
    return str(filepath)

print('✅ Export functions defined')
# Out:
# ✅ Export functions defined

# %% [markdown]
# ## 🎨 Display Functions

# %%
def display_guide_summary(guide: CompleteDIYGuide):
    """Display a nice summary of the guide."""
    
    html = f"""
    <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); 
                padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
        <h2 style="margin-top: 0;">📋 {guide.topic}</h2>
        <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin-top: 15px;">
            <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
                <strong>Difficulty:</strong><br>{guide.difficulty}
            </div>
            <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
                <strong>Time:</strong><br>{guide.duration_estimate}
            </div>
            <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
                <strong>Total Cost:</strong><br>{format_currency(guide.cost_breakdown.total_project)}
            </div>
            <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
                <strong>Steps:</strong><br>{len(guide.steps)}
            </div>
        </div>
    </div>
    
    <div style="background: #f8f9fa; padding: 20px; border-radius: 10px; margin: 20px 0;">
        <h3>📊 Cost Breakdown</h3>
        <div style="margin: 10px 0;">
            <strong>Materials:</strong> {format_currency(guide.cost_breakdown.total_materials)}<br>
            <strong>Tools:</strong> {format_currency(guide.cost_breakdown.total_tools)}<br>
        </div>
        <div style="background: #e9ecef; padding: 10px; border-radius: 5px; margin-top: 10px;">
            <strong>Materials Needed:</strong> {len(guide.materials)}<br>
            <strong>Tools Required:</strong> {len(guide.tools)}<br>
            <strong>Safety Guidelines:</strong> {len(guide.safety_guidelines)}
        </div>
    </div>
    """
    
    display(HTML(html))

print('✅ Display functions defined')
# Out:
# ✅ Display functions defined

# %% [markdown]
# ## 🚀 Generate Your DIY Guide
#
# Now let's create a complete DIY guide! Modify the parameters below to customize your guide.

# %%
# Configuration
DIY_TOPIC = "How to Install a French Drain"
BUDGET_RANGE = "moderate"  # Options: 'budget', 'moderate', 'premium'
GENERATE_IMAGES = True  # Set to False to skip image generation

# Generate the guide
guide = generate_complete_guide(
    topic=DIY_TOPIC,
    budget_range=BUDGET_RANGE,
    generate_images=GENERATE_IMAGES
)

# Display summary
display_guide_summary(guide)
# Out:
# 🔄 Generating complete DIY guide for: How to Install a French Drain
# 💰 Budget range: moderate
# 🎨 Generate images: True
#
# 📝 Step 1: Generating guide content...
# ✅ Successfully parsed JSON response
# ✅ Generated 8 steps with 6 materials and 11 tools
#
# 🎨 Step 2: Generating images for 8 steps...
#   Generating image 1/8: Establish Trench Layout and Grade...
# C:\Users\ramma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\genai\_common.py:473: UserWarning: block_some is not a valid SafetyFilterLevel
#   warnings.warn(f"{value} is not a valid {cls.__name__}")
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 2/8: Dig the Trench...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 3/8: Lay Geotextile Filter Fabric...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 4/8: Add Initial Gravel Layer...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 5/8: Install Perforated Drain Pipe...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 4/8: Add Initial Gravel Layer...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 5/8: Install Perforated Drain Pipe...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 6/8: Cover Pipe with Gravel...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 7/8: Fold Fabric and Add Final Gravel/Backfill...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 8/8: Backfill and Finish the Surface...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 6/8: Cover Pipe with Gravel...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 7/8: Fold Fabric and Add Final Gravel/Backfill...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 8/8: Backfill and Finish the Surface...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
# ✅ Image generation complete
#
# ✅ Complete guide generated successfully!
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
# ✅ Image generation complete
#
# ✅ Complete guide generated successfully!
#     <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#                 padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#         <h2 style="margin-top: 0;">📋 How to Install a French Drain</h2>
#         <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin-top: 15px;">
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Difficulty:</strong><br>Intermediate
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Time:</strong><br>2-3 full weekends (40-60 hours total) for a 50-foot drain, depending on soil conditions and terrain.
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Total Cost:</strong><br>$911.68
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Steps:</strong><br>8
#             </div>
#         </div>
#     </div>
#
#     <div style="background: #f8f9fa; padding: 20px; border-radius: 10px; margin: 20px 0;">
#         <h3>📊 Cost Breakdown</h3>
#         <div style="margin: 10px 0;">
#             <strong>Materials:</strong> $332.91<br>
#             <strong>Tools:</strong> $578.77<br>
#         </div>
#         <div style="background: #e9ecef; padding: 10px; border-radius: 5px; margin-top: 10px;">
#             <strong>Materials Needed:</strong> 6<br>
#             <strong>Tools Required:</strong> 11<br>
#             <strong>Safety Guidelines:</strong> 21
#         </div>
#     </div>

# %% [markdown]
# ## 💾 Export Guide to Markdown

# %%
# Export the guide
output_file = export_guide_to_markdown(guide)

print(f"\n📄 Guide exported successfully!")
print(f"📍 Location: {output_file}")
# Out:
# ✅ Exported to: ..\exports\diy_guides\how_to_install_a_french_drain.md
#
# 📄 Guide exported successfully!
# 📍 Location: ..\exports\diy_guides\how_to_install_a_french_drain.md

# %% [markdown]
# ## 📊 View Guide Details

# %%
# View materials with pricing
print("🛒 MATERIALS LIST WITH PRICING\n" + "="*60)

for i, material in enumerate(guide.materials, 1):
    print(f"\n{i}. {material.name}")
    print(f"   Description: {material.description}")
    if material.specifications:
        print(f"   Specs: {material.specifications}")
    if material.estimated_price:
        print(f"   Price Range: {material.estimated_price}")
    
    if material.retailers:
        print("\n   Where to Buy:")
        for retailer in material.retailers:
            print(f"   - {retailer['name']}: {retailer.get('price', 'N/A')}")
            if retailer.get('product_name'):
                print(f"     Product: {retailer['product_name']}")
# Out:
# 🛒 MATERIALS LIST WITH PRICING
# ============================================================
#
# 1. Perforated Corrugated Drain Pipe with Sock
#    Description: The main component of the French drain, designed to collect and transport subsurface water. The sock prevents sediment from entering the pipe.
#    Specs: 4-inch diameter, 100-foot roll, perforated with filtering sock attached.
#    Price Range: $60.00 - $85.00
#
#    Where to Buy:
#    - Home Depot: $64.97
#      Product: NDS 4 in. x 100 ft. Corrugated Perforated Drain Pipe with Sock
#    - Lowe's: $69.98
#      Product: ADS 4-in x 100-ft Corrugated Perforated Drain Pipe with Sock
#    - Amazon: $75.00
#      Product: Flex-Drain 4 in. x 100 ft. Perforated Corrugated Drain Pipe with Sock
#
# 2. Non-Woven Geotextile Filter Fabric
#    Description: A heavy-duty fabric that lines the trench, preventing soil and fines from mixing with the gravel and clogging the drain system, while allowing water to pass through.
#    Specs: 3-foot wide x 100-foot long roll, 3 oz. per square yard minimum.
#    Price Range: $30.00 - $60.00
#
#    Where to Buy:
#    - Home Depot: $39.97
#      Product: DeWitt 3 ft. x 100 ft. 3 oz. Weed Barrier Fabric
#    - Lowe's: $42.98
#      Product: Vigoro 3-ft x 100-ft Landscape Fabric
#    - Amazon: $45.00
#      Product: ECOgardener Premium 5oz Pro Garden Weed Barrier Landscape Fabric Roll 3ft x 100ft
#
# 3. Washed Drainage Gravel
#    Description: Clean, angular aggregate (e.g., #57 stone) used to surround the drainage pipe. It provides voids for water flow and supports the pipe, while the 'washed' characteristic means it's free of fine particles that could clog the system.
#    Specs: 1/2-inch to 1-inch angular washed stone (e.g., #57 stone). Quantity: 1.5 cubic yards per 50 linear feet of trench (based on 12" wide x 18" deep trench, 10" of gravel).
#    Price Range: $60.00 - $120.00 per cubic yard (plus delivery)
#
#    Where to Buy:
#    - Local Landscape Supply Yard: $40.00 - $80.00 per cubic yard
#      Product: #57 Washed Stone / Drainage Stone
#    - Home Depot: $5.00 - $7.00 per 0.5 cu ft bag
#      Product: Vigoro 0.5 cu ft. Pea Gravel
#    - Lowe's: $5.00 - $7.00 per 0.5 cu ft bag
#      Product: River Rock / Decorative Stone
#
# 4. Pop-Up Drainage Emitter
#    Description: A discreet, spring-loaded cap that connects to the end of the drain pipe, allowing collected water to discharge safely onto the surface away from the problem area.
#    Specs: 4-inch diameter, compatible with corrugated drain pipe.
#    Price Range: $15.00 - $25.00
#
#    Where to Buy:
#    - Home Depot: $17.97
#      Product: NDS 4 in. Pop-Up Drainage Emitter
#    - Lowe's: $18.98
#      Product: NDS 4-in Pop-Up Drainage Emitter
#    - Amazon: $20.00
#      Product: NDS 400 4" Pop-Up Drainage Emitter
#
# 5. Topsoil
#    Description: Used for backfilling the top layer of the trench to restore the ground surface.
#    Specs: 1 cubic yard (for 50 ft trench, 12" wide, 4" topsoil layer).
#    Price Range: $30.00 - $70.00 per cubic yard (plus delivery)
#
#    Where to Buy:
#    - Local Landscape Supply Yard: $25.00 - $60.00 per cubic yard
#      Product: Screened Topsoil
#    - Home Depot: $3.00 - $5.00 per 1 cu ft bag
#      Product: Vigoro 1 cu ft. Topsoil
#
# 6. Sod or Grass Seed
#    Description: For restoring the lawn over the trench.
#    Specs: Sufficient quantity to cover the trench line (e.g., 50 sq ft of sod or 1 small bag of grass seed).
#    Price Range: $20.00 - $100.00
#
#    Where to Buy:
#    - Home Depot: $3.00 - $6.00 per roll of sod (1-2 sq ft each)
#      Product: Fresh Cut Sod
#    - Lowe's: $3.00 - $6.00 per roll of sod
#      Product: Fresh Cut Sod

# %%
# View tools with pricing
print("🔧 TOOLS REQUIRED WITH PRICING\n" + "="*60)

for i, tool in enumerate(guide.tools, 1):
    print(f"\n{i}. {tool.name}")
    print(f"   Use: {tool.description}")
    if tool.specifications:
        print(f"   Specs: {tool.specifications}")
    if tool.estimated_price:
        print(f"   Price Range: {tool.estimated_price}")
    
    if tool.retailers:
        print("\n   Where to Buy:")
        for retailer in tool.retailers:
            print(f"   - {retailer['name']}: {retailer.get('price', 'N/A')}")
            if retailer.get('product_name'):
                print(f"     Product: {retailer['product_name']}")
# Out:
# 🔧 TOOLS REQUIRED WITH PRICING
# ============================================================
#
# 1. Trenching Shovel (or Ditch Digging Shovel)
#    Use: Narrow, pointed shovel designed for digging trenches. Essential for manual digging.
#    Specs: Blade width 4-6 inches, long handle.
#    Price Range: $25.00 - $45.00
#
#    Where to Buy:
#    - Home Depot: $29.98
#      Product: Fiskars Pro D-Handle Digging Shovel
#    - Lowe's: $32.98
#      Product: Kobalt D-Handle Steel Digging Shovel
#
# 2. Square Point Shovel
#    Use: Used for scooping loose soil and gravel, and for leveling the trench bottom.
#    Specs: Standard square blade, long or D-handle.
#    Price Range: $20.00 - $40.00
#
#    Where to Buy:
#    - Home Depot: $24.97
#      Product: Husky 48 in. Wood Handle Square Point Shovel
#    - Lowe's: $26.98
#      Product: Kobalt Wood Handle Square Point Shovel
#
# 3. Pickaxe (or Mattock)
#    Use: Crucial for breaking up compacted soil, clay, or small rocks.
#    Specs: Standard pickaxe with sharp point and broad blade.
#    Price Range: $30.00 - $60.00
#
#    Where to Buy:
#    - Home Depot: $39.97
#      Product: Razor-Back 5 lb. Pick Mattock with 36 in. Fiberglass Handle
#    - Lowe's: $42.98
#      Product: Kobalt 5-lb Steel Pick Mattock
#
# 4. Wheelbarrow
#    Use: Essential for moving excavated soil and gravel efficiently.
#    Specs: 6-8 cubic foot capacity, pneumatic tire recommended.
#    Price Range: $80.00 - $150.00
#
#    Where to Buy:
#    - Home Depot: $99.00
#      Product: Jackson Professional Tools 6 cu. ft. Steel Tray Wheelbarrow
#    - Lowe's: $89.98
#      Product: Kobalt 6 cu ft Steel Wheelbarrow
#
# 5. Measuring Tape
#    Use: For measuring trench dimensions and pipe lengths.
#    Specs: 25-foot or 30-foot retractable tape measure.
#    Price Range: $10.00 - $25.00
#
#    Where to Buy:
#    - Home Depot: $14.97
#      Product: Stanley FATMAX 25 ft. x 1-1/4 in. Tape Measure
#
# 6. 4-foot Level
#    Use: Critical for establishing and verifying the trench slope.
#    Specs: 48-inch box beam or I-beam level.
#    Price Range: $30.00 - $60.00
#
#    Where to Buy:
#    - Home Depot: $39.97
#      Product: Empire 48 in. True Blue Box Level
#    - Lowe's: $34.98
#      Product: Kobalt 48-in Box Beam Level
#
# 7. String Line and Stakes
#    Use: For marking the trench path and establishing grade/slope.
#    Specs: Nylon string line (100 ft), wood or metal stakes (4-6 pieces).
#    Price Range: $10.00 - $20.00
#
#    Where to Buy:
#    - Home Depot: $9.97
#      Product: Empire 100 ft. Braided Nylon Line and Stakes
#
# 8. Utility Knife
#    Use: For cutting landscape fabric and pipe sock.
#    Specs: Retractable blade, heavy-duty.
#    Price Range: $5.00 - $15.00
#
#    Where to Buy:
#    - Home Depot: $9.97
#      Product: Husky Retractable Utility Knife
#
# 9. Hand Tamper (Manual)
#    Use: For compacting the final backfill material, preventing settling.
#    Specs: 10x10 inch or 8x8 inch steel plate, long handle.
#    Price Range: $30.00 - $50.00
#
#    Where to Buy:
#    - Home Depot: $34.97
#      Product: Razor-Back 10 in. x 10 in. Steel Tamper
#
# 10. Garden Rake
#    Use: For spreading gravel and topsoil evenly.
#    Specs: Bow rake or landscape rake.
#    Price Range: $20.00 - $40.00
#
#    Where to Buy:
#    - Home Depot: $24.97
#      Product: HDX 60 in. Wood Handle Bow Rake
#
# 11. Trenching Machine (Trencher)
#    Use: Power equipment for digging trenches, significantly reduces labor for long runs.
#    Specs: Walk-behind or ride-on, capable of 18-24 inch depth, 6-12 inch width.
#    Price Range: N/A (rental recommended)
#
#    Where to Buy:
#    - Home Depot Tool Rental: $150.00 - $300.00 per day
#      Product: Ditch Witch or Barreto Walk-Behind Trencher
#    - Lowe's Tool Rental: $150.00 - $300.00 per day
#      Product: Various Trencher Models
#    - Local Equipment Rental Shops: $120.00 - $250.00 per day
#      Product: Various Trencher Models

# %%
# View safety guidelines
print("⚠️ SAFETY GUIDELINES\n" + "="*60)

critical = [sg for sg in guide.safety_guidelines if sg.importance == 'critical']
high = [sg for sg in guide.safety_guidelines if sg.importance == 'high']
medium = [sg for sg in guide.safety_guidelines if sg.importance == 'medium']

if critical:
    print("\n🚨 CRITICAL WARNINGS:")
    for sg in critical:
        print(f"   - {sg.description}")

if high:
    print("\n⚡ IMPORTANT PRECAUTIONS:")
    for sg in high:
        print(f"   - {sg.description}")

if medium:
    print("\n✓ ADDITIONAL SAFETY TIPS:")
    for sg in medium:
        print(f"   - {sg.description}")
# Out:
# ⚠️ SAFETY GUIDELINES
# ============================================================
#
# 🚨 CRITICAL WARNINGS:
#    - Before any digging, ALWAYS call 811 (Dig Safe) at least 3 business days in advance to have underground utility lines (electrical, gas, water, sewer, communication) marked. Hitting a utility line can cause serious injury, death, or massive property damage.
#    - Heavy-duty work gloves (e.g., leather or nitrile-dipped) to protect hands from blisters, cuts, and abrasions.
#    - ANSI-approved safety glasses or goggles to protect eyes from flying debris, dust, and splashes.
#    - Steel-toe work boots with good ankle support and slip-resistant soles to protect feet from falling objects and provide stable footing.
#    - If working in a trench deeper than 4 feet, consider trench shoring or sloping the sides to prevent collapse, especially in unstable soil. Never work alone in a deep trench.
#    - If you hit a utility line (gas, electrical, water, sewer), immediately stop work, evacuate the area, and call 911 and your utility company. Do NOT attempt to fix it yourself.
#
# ⚡ IMPORTANT PRECAUTIONS:
#    - Be aware of potential structural hazards, especially if digging near foundations, retaining walls, or large trees. Undermining these structures can cause instability.
#    - Long-sleeved shirts and long pants to protect skin from sun exposure, scratches, and irritants.
#    - Stay hydrated by drinking plenty of water, especially on hot days. Take frequent breaks to avoid heat exhaustion or fatigue.
#    - Use proper lifting techniques: bend your knees, keep your back straight, and lift with your legs. Avoid twisting. Get help for heavy loads like bags of gravel or large tools.
#    - If renting power equipment, ensure you understand its operation and safety features thoroughly before use.
#    - Be mindful of children and pets, keeping them away from the active work zone.
#    - If you encounter unexpected structural issues, large rocks or boulders you can't manage, or significant amounts of groundwater that make digging unsafe.
#
# ✓ ADDITIONAL SAFETY TIPS:
#    - If your property has any history of chemical spills or unknown buried materials, proceed with extreme caution. Wear appropriate respirators and gloves, and if unsure, consult with a professional.
#    - Ear protection (earplugs or earmuffs) if using power tools like a trencher or plate compactor for extended periods.
#    - Maintain a clean work area to prevent trips and falls. Keep tools organized and put away when not in use.
#    - Plan your work to avoid digging during heavy rain, which can make trenches unstable and muddy, increasing risk.
#    - Ensure adequate lighting if working near dusk or dawn.
#    - Avoid contact with poison ivy, oak, or other irritating plants. Wear appropriate clothing and wash thoroughly after working.
#    - If the project scope becomes too large or complex, or if you feel uncomfortable or out of your depth at any point.
#    - If your drainage problem is severe, persistent, or involves your home's foundation, it may warrant a professional drainage contractor or structural engineer.

# %%
# View step-by-step instructions
print("📖 STEP-BY-STEP INSTRUCTIONS\n" + "="*60)

for step in guide.steps:
    print(f"\n{'='*60}")
    print(f"STEP {step.step_number}: {step.title}")
    print(f"{'='*60}")
    print(f"\n{step.description}\n")
    
    print("Instructions:")
    for i, instruction in enumerate(step.detailed_instructions, 1):
        print(f"  {i}. {instruction}")
    
    if step.tips:
        print("\n💡 Pro Tips:")
        for tip in step.tips:
            print(f"  - {tip}")
    
    if step.warnings:
        print("\n⚠️ Warnings:")
        for warning in step.warnings:
            print(f"  - {warning}")
    
    if step.image_path:
        print(f"\n📸 Image saved: {step.image_path}")
# Out:
# 📖 STEP-BY-STEP INSTRUCTIONS
# ============================================================
#
# ============================================================
# STEP 1: Establish Trench Layout and Grade
# ============================================================
#
# Accurately mark the trench path and establish the required slope using stakes and string line. This is crucial for effective drainage.
#
# Instructions:
#   1. Using spray paint or powdered chalk, mark the exact path of your French drain on the ground. Ensure the path avoids any marked utility lines.
#   2. At the starting point (highest elevation), drive a stake into the ground. Tie a string line to this stake at the desired depth for the top of your drain, typically 18-24 inches below the finished grade.
#   3. Walk the length of your proposed trench to the discharge point (lowest elevation). Drive another stake at this point. Calculate the total drop needed (e.g., 50 feet * 1/8 inch/foot = 6.25 inches).
#   4. Tie the string line to the second stake, ensuring it has the calculated downward slope from the first stake. Use a line level (or a 4-foot level resting on the string) to verify the consistent slope along the entire run.
#   5. Adjust stakes and string as needed to achieve a smooth, consistent slope. This string line will serve as your guide for the trench bottom depth.
#
# 💡 Pro Tips:
#   - For longer runs, use intermediate stakes to prevent the string line from sagging.
#   - A laser level can make setting the grade much easier and more accurate if available (rental option).
#   - Consider the final look: where will the drain outlet be, and how will it blend into the landscape?
#
# ⚠️ Warnings:
#   - Incorrect slope will lead to standing water in the drain, rendering it ineffective or even causing pipe damage.
#
# ============================================================
# STEP 2: Dig the Trench
# ============================================================
#
# Excavate the trench to the required depth and width, carefully maintaining the established slope.
#
# Instructions:
#   1. Begin digging at the highest point of the trench. Aim for a trench depth of 18-24 inches and a width of 12-18 inches. The width helps accommodate the fabric and gravel.
#   2. Use a trenching shovel or a rented trencher to remove soil. Place excavated soil onto a tarp or directly into a wheelbarrow for easy removal or storage (if reusing for backfill).
#   3. Continuously check the depth of the trench using your measuring tape and the string line as a guide. The bottom of the trench should consistently follow the established slope.
#   4. Use a square-point shovel or a hand trowel to smooth and level the bottom of the trench, ensuring there are no high or low spots.
#   5. If you encounter roots, use a root saw or an axe to cut them cleanly. If you hit large rocks or compacted soil, use a pickaxe to break them apart.
#   6. Ensure the trench walls are as vertical as possible to maintain structural integrity and prevent collapse.
#
# 💡 Pro Tips:
#   - If renting a trencher, practice in an inconspicuous area first. They can be powerful and require careful handling.
#   - For manual digging, dig in short sections, moving the soil as you go to avoid creating large piles that block access.
#   - Keep the excavated soil organized. If reusing for backfill, separate topsoil from subsoil.
#
# ⚠️ Warnings:
#   - Never dig near marked utility lines. If you uncover an unmarked line, stop immediately and call 811 again.
#   - Ensure trench walls are stable. If digging deeper than 4 feet or in unstable soil, consider shoring the trench or widening the top to create a safer slope.
#   - Watch for signs of fatigue and take breaks. Digging is strenuous work.
#
# ============================================================
# STEP 3: Lay Geotextile Filter Fabric
# ============================================================
#
# Line the trench with permeable filter fabric to prevent soil and silt from clogging the drain system.
#
# Instructions:
#   1. Unroll the non-woven geotextile filter fabric along the length of the trench.
#   2. Carefully drape the fabric into the trench, ensuring it covers the bottom and extends up both sides. Leave at least 12-18 inches of excess fabric on each side, draping over the trench edges.
#   3. Overlap sections of fabric by at least 12 inches if your trench is longer than your fabric roll or wider than the fabric width. Secure overlaps with landscape staples or rocks to prevent shifting.
#   4. Smooth out any wrinkles or folds in the fabric along the trench bottom and sides. The fabric should conform to the shape of the trench.
#
# 💡 Pro Tips:
#   - Work on a calm day to prevent the fabric from blowing away.
#   - If the trench is very long, unroll the fabric in manageable sections.
#   - Don't stretch the fabric too tightly; allow for some slack to accommodate the gravel and pipe.
#
# ⚠️ Warnings:
#   - Ensure the fabric is non-woven and permeable. Plastic sheeting or weed barriers without adequate permeability will trap water instead of draining it.
#
# ============================================================
# STEP 4: Add Initial Gravel Layer
# ============================================================
#
# Create a base layer of washed drainage gravel at the bottom of the fabric-lined trench.
#
# Instructions:
#   1. Shovel or pour the washed drainage gravel (e.g., #57 stone) directly into the fabric-lined trench.
#   2. Spread the gravel evenly to create a base layer approximately 2-4 inches deep along the entire length of the trench.
#   3. Use a square-point shovel or a rake to level the gravel. Ensure the gravel layer maintains the consistent slope established in Step 1.
#   4. Check the slope of the gravel bed using your 4-foot level. This base layer is crucial for supporting the pipe and facilitating initial water flow.
#
# 💡 Pro Tips:
#   - Having gravel delivered in bulk is more cost-effective and efficient than buying bags. Use your wheelbarrow to transport it to the trench.
#   - Don't compact this layer. The voids between the stones are essential for water flow.
#
# ⚠️ Warnings:
#   - Do not use 'all-purpose' or 'crusher run' gravels that contain fines (sand, dust). These will quickly clog your drain system.
#
# ============================================================
# STEP 5: Install Perforated Drain Pipe
# ============================================================
#
# Lay the perforated drain pipe on top of the gravel base, ensuring perforations are correctly oriented and the pipe follows the trench slope.
#
# Instructions:
#   1. Unroll the perforated drain pipe with the sock attached. If using a roll, start from the highest point of the trench and unroll it down the slope.
#   2. Carefully place the pipe directly onto the leveled gravel bed. Ensure the pipe's perforations (holes) are facing downwards. This allows water to enter the pipe from the bottom where it collects.
#   3. Connect sections of pipe using appropriate couplers if necessary. Ensure connections are secure.
#   4. Verify that the pipe maintains the correct slope along its entire length by placing your 4-foot level on top of the pipe. Adjust the gravel beneath the pipe as needed to achieve the proper grade.
#   5. At the discharge end, attach the pop-up drainage emitter or connect to your designated outlet point. Ensure the emitter is positioned to release water away from your foundation or other sensitive areas.
#
# 💡 Pro Tips:
#   - If the pipe comes in a coil, it may have a tendency to curl up. You can weigh it down with a few shovelfuls of gravel as you lay it.
#   - Ensure the pipe sock is intact and covers all perforations. Repair any tears with landscape fabric tape if necessary.
#
# ⚠️ Warnings:
#   - Orienting the perforations upwards will cause the pipe to fill with sediment more quickly and reduce its effectiveness.
#   - Do not kink the pipe, especially at turns. Use gentle curves or appropriate fittings for sharp turns.
#
# ============================================================
# STEP 6: Cover Pipe with Gravel
# ============================================================
#
# Completely encase the drain pipe with another layer of washed drainage gravel.
#
# Instructions:
#   1. Carefully shovel or pour more washed drainage gravel over and around the installed pipe.
#   2. Fill the trench with gravel until it covers the pipe by at least 6-8 inches. The gravel should extend to within about 6-8 inches from the top of the trench, leaving space for the filter fabric overlap and topsoil.
#   3. Distribute the gravel evenly, ensuring it completely surrounds the pipe and fills all voids. Do not compact this layer; the open spaces are critical for water flow.
#   4. Use a rake or square-point shovel to smooth the top of the gravel layer.
#
# 💡 Pro Tips:
#   - Work slowly to avoid dislodging the pipe or tearing the fabric.
#   - If you have a large amount of gravel, consider using a gravel chute or a second person to help distribute it.
#
# ⚠️ Warnings:
#   - Ensure no soil or debris falls into the gravel layer during this step, as it can compromise drainage.
#
# ============================================================
# STEP 7: Fold Fabric and Add Final Gravel/Backfill
# ============================================================
#
# Fold the excess filter fabric over the gravel and add a final layer of gravel or initial backfill.
#
# Instructions:
#   1. Take the excess filter fabric draped over the sides of the trench and fold it over the top of the gravel layer, essentially creating a 'fabric burrito' around the gravel and pipe.
#   2. Ensure the fabric overlaps by at least 6-12 inches to fully encapsulate the gravel. This prevents any soil from migrating into the drainage layer from above.
#   3. If desired, add a final 1-2 inch layer of washed drainage gravel on top of the folded fabric. This provides an additional permeable layer directly beneath the topsoil.
#   4. Alternatively, if you're directly backfilling with soil, begin adding your separated subsoil (if applicable) or a thin layer of topsoil over the folded fabric.
#
# 💡 Pro Tips:
#   - Use a few landscape staples to secure the overlapping fabric edges if needed, especially on slopes.
#   - The 'fabric burrito' method is highly effective for long-term drain performance.
#
# ⚠️ Warnings:
#   - Do not leave gaps in the folded fabric. Any exposed gravel can allow soil to infiltrate and clog the system.
#
# ============================================================
# STEP 8: Backfill and Finish the Surface
# ============================================================
#
# Fill the remainder of the trench with topsoil and restore the surface with sod or grass seed.
#
# Instructions:
#   1. Carefully backfill the remaining trench space with your reserved topsoil. Fill it slightly higher than the surrounding grade to account for settling.
#   2. Lightly compact the topsoil with a hand tamper or by walking over it. Avoid over-compacting, as this can impede water absorption into the drain.
#   3. If you saved sod, carefully place the sod pieces back over the trench, ensuring they fit snugly. Water them immediately and regularly to help them establish.
#   4. If using grass seed, spread a layer of grass seed over the topsoil according to package directions. Lightly rake it in and cover with a thin layer of straw to prevent erosion and aid germination. Water regularly.
#   5. Ensure the final grade of the surface slopes slightly away from any structures (like your house) to direct surface water away.
#
# 💡 Pro Tips:
#   - It's better to overfill slightly, as soil will settle over time. You can always add more later if needed.
#   - Watering helps the soil settle and compact naturally.
#
# ⚠️ Warnings:
#   - Do not create a 'ditch' where the French drain is installed, as this will collect surface water rather than letting it filter to the drain below.

# %% [markdown]
# ## 🎯 Quick Generate Function
#
# Use this cell to quickly generate guides for different topics

# %%
def quick_generate(topic: str, budget: str = 'moderate', images: bool = True):
    """Quickly generate and export a DIY guide."""
    print(f"\n🚀 Generating guide for: {topic}\n")
    
    # Generate
    guide = generate_complete_guide(topic, budget, images)
    
    # Display
    display_guide_summary(guide)
    
    # Export
    output_file = export_guide_to_markdown(guide)
    
    print(f"\n✅ Complete! Guide saved to: {output_file}")
    return guide

# Example usage:
# guide = quick_generate("How to Build a Deck", budget='moderate', images=True)
# guide = quick_generate("How to Install Laminate Flooring", budget='budget', images=False)
# guide = quick_generate("How to Tile a Bathroom", budget='premium', images=True)

print("✅ Quick generate function ready!")
print("\nExample usage:")
print('guide = quick_generate("How to Build a Deck")')
# Out:
# ✅ Quick generate function ready!
#
# Example usage:
# guide = quick_generate("How to Build a Deck")

# %% [markdown]
# ## 📝 Additional Examples
#
# Uncomment any of these to generate more guides:

# %%
# Example 1: Install a Ceiling Fan
guide = quick_generate("How to Install a Ceiling Fan", budget='moderate', images=True)

# Example 2: Build a Raised Garden Bed
# guide = quick_generate("How to Build a Raised Garden Bed", budget='budget', images=True)

# Example 3: Install Recessed Lighting
# guide = quick_generate("How to Install Recessed Lighting", budget='moderate', images=True)

# Example 4: Build a Shed
# guide = quick_generate("How to Build a Storage Shed", budget='premium', images=True)

# Example 5: Install Vinyl Plank Flooring
# guide = quick_generate("How to Install Vinyl Plank Flooring", budget='moderate', images=True)

print("Uncomment any example above to generate a guide!")
# Out:
# 🚀 Generating guide for: How to Install a Ceiling Fan
#
# 🔄 Generating complete DIY guide for: How to Install a Ceiling Fan
# 💰 Budget range: moderate
# 🎨 Generate images: True
#
# 📝 Step 1: Generating guide content...
# ✅ Successfully parsed JSON response
# ✅ Generated 9 steps with 7 materials and 9 tools
#
# 🎨 Step 2: Generating images for 9 steps...
#   Generating image 1/9: Disconnect Power and Remove Old Fixture...
# ✅ Successfully parsed JSON response
# ✅ Generated 9 steps with 7 materials and 9 tools
#
# 🎨 Step 2: Generating images for 9 steps...
#   Generating image 1/9: Disconnect Power and Remove Old Fixture...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 2/9: Inspect and Prepare Electrical Box...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 3/9: Assemble Fan Components (Pre-Installation)...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 2/9: Inspect and Prepare Electrical Box...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 3/9: Assemble Fan Components (Pre-Installation)...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 4/9: Mount the Mounting Bracket...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 5/9: Make Electrical Connections...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 4/9: Mount the Mounting Bracket...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 5/9: Make Electrical Connections...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 6/9: Secure Fan Motor Assembly...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 7/9: Install Fan Blades...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 6/9: Secure Fan Motor Assembly...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 7/9: Install Fan Blades...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 8/9: Install Light Kit (if applicable)...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 9/9: Test and Finalize...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 8/9: Install Light Kit (if applicable)...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
#   Generating image 9/9: Test and Finalize...
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
# ✅ Image generation complete
#
# ✅ Complete guide generated successfully!
#     ⚠️ Failed to generate image: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Only block_low_and_above is supported for
# ✅ Image generation complete
#
# ✅ Complete guide generated successfully!
#     <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#                 padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#         <h2 style="margin-top: 0;">📋 How to Install a Ceiling Fan</h2>
#         <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin-top: 15px;">
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Difficulty:</strong><br>Intermediate
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Time:</strong><br>3-5 hours (1 hour prep, 2-4 hours work, 30 minutes cleanup)
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Total Cost:</strong><br>$516.69
#             </div>
#             <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
#                 <strong>Steps:</strong><br>9
#             </div>
#         </div>
#     </div>
#
#     <div style="background: #f8f9fa; padding: 20px; border-radius: 10px; margin: 20px 0;">
#         <h3>📊 Cost Breakdown</h3>
#         <div style="margin: 10px 0;">
#             <strong>Materials:</strong> $224.35<br>
#             <strong>Tools:</strong> $292.34<br>
#         </div>
#         <div style="background: #e9ecef; padding: 10px; border-radius: 5px; margin-top: 10px;">
#             <strong>Materials Needed:</strong> 7<br>
#             <strong>Tools Required:</strong> 9<br>
#             <strong>Safety Guidelines:</strong> 12
#         </div>
#     </div>
# ✅ Exported to: ..\exports\diy_guides\how_to_install_a_ceiling_fan.md
#
# ✅ Complete! Guide saved to: ..\exports\diy_guides\how_to_install_a_ceiling_fan.md
# Uncomment any example above to generate a guide!
